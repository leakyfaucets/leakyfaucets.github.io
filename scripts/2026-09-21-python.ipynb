# %% [markdown]
# ## 字符串

# %% [markdown]
# ## 数值类型

# %%
print(0.1+0.2)
print(3.0*(4+2.1))
print(18/(3+2*3))
print(3*2**2)
print(19%2)
print(19//2)
# Out:
# 0.30000000000000004
# 18.299999999999997
# 2.0
# 12
# 1
# 9
