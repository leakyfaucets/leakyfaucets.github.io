# %% [markdown]
# 期末为项目报告不限定主题，自由发挥，4人一组，全组分数相同
#
# 派森小木屋、datawhale
#
# 考勤40%，期末60%
#
# 数据科学会议：SIGKDD、SIGMOD、SIGIR、VLDB、ICDE、CIKM
#
# AI顶会：ACL、AAAI、EMNCP、CVPR、NumIPS
#
# kaggle比赛、阿里天池
#
# 相关不等于因果
#
# 欠拟合和过拟合
#
# overleaf：latex在线编辑器
