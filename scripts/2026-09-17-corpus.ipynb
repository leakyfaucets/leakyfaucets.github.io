# %% [markdown]
# 分数：出勤20+平时作业3次30分+期末论文50，不点名，出勤看期末论文有没有知识性问题。
# 三次作业：
# 1. 小型语言数据库建设步骤&讨论
# 2. 论文选题
# 3. 研究问题及研究设计
# 期末论文寒假结束后提交。中文7000-10000字，英文6000-8000词。
# 题目、摘要、关键词、参考文献都要有。

# %% [markdown]
# ## 引言
